# %% [markdown]
# <a href="https://colab.research.google.com/github/nadir177/nadir/blob/main/FaceFusion_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/facefusion/facefusion.git
# %cd /content/facefusion
# !pip install -r requirements.txt
# !pip install onnxruntime-gpu
# Out:
# Cloning into 'facefusion'...
# remote: Enumerating objects: 5992, done.
# remote: Counting objects: 100% (651/651), done.
# remote: Compressing objects: 100% (176/176), done.
# remote: Total 5992 (delta 559), reused 489 (delta 475), pack-reused 5341 (from 4)
# Receiving objects: 100% (5992/5992), 30.98 MiB | 26.00 MiB/s, done.
# Resolving deltas: 100% (3986/3986), done.
# /content/facefusion
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 24.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 MB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 69.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.5/17.5 MB 55.8 MB/s eta 0:00:00
# ...

# %%
# Path to the default layout file
file_path = '/content/facefusion/facefusion/uis/layouts/default.py'

# Read the content of the file
with open(file_path, 'r') as file:
    content = file.read()

# Replace the line to enable sharing
updated_content = content.replace('ui.launch(show_api = False)', 'ui.launch(show_api = False, share=True)')

# Write the updated content back to the file
with open(file_path, 'w') as file:
    file.write(updated_content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_21073/103256955.py in <cell line: 0>()
#       3
#       4 # Read the content of the file
# ----> 5 with open(file_path, 'r') as file:
#       6     content = file.read()
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/facefusion/facefusion/uis/layouts/default.py'

# %%
# !python facefusion.py run
# Out:
# python3: can't open file '/content/facefusion.py': [Errno 2] No such file or directory
